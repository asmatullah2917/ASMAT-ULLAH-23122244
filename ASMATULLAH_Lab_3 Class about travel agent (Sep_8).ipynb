# %% [markdown]
# <a href="https://colab.research.google.com/github/asmatullah2917/ASMAT-ULLAH-23122244/blob/main/ASMATULLAH_Lab_3%20Class%20about%20travel%20agent%20(Sep_8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: Hi
#
# Agent:
#  Assalam-o-Alaikum! Welcome to Pakistan Tourism. As your dedicated travel agent, I am thrilled to help you plan an unforgettable, pocket-friendly adventure.
#
# Since you are looking for a student-friendly trip, I have designed the perfect itinerary for **Hunza Valley (Gilgit-Baltistan)**. Known as the "Heaven on Earth," Hunza is safe, incredibly beautiful, culturally rich, and highly affordable if planned right.
#
# Here is your complete, student-friendly travel plan:
#
# ---
#
# ### 1. Destination Overview
# **Hunza Valley** is nestled in the northern part of Gilgit-Baltistan, surrounded by majestic peaks like Rakaposhi and Ladyfinger. It is famous for its crystal-clear lakes, historic forts, friendly locals, and a 99% literacy rate.
# *   **Why it's great for students:** It is one of the safest tourist destinations in Pakistan, has budget-friendly hostels/homestays, and offers a mix of adventure, history, and photography spots.
# *   **Best Time to Visit:** May to October (for lush greenery and pleasant weather) or October to November (for stunning autumn colors).
#
# ---
#
# ### 2. Budget Travel Options (Routes starting from Islamabad)
# *Prices are approximate and subject to change, but they reflect current student budget estimates.*
#
# *   **Option A: The Budget King (Bus/Coaster)**
#     *   **Route:** Islamabad to Gilgit/Hunza via NATCO or Faisal Movers.
#     *   **Approx. Cost:** PKR 4,500 – 6,000 (One-way)
#     *   **Travel Time:** 14–16 hours via the Karakoram Highway or Babusar Top (seasonal).
# *   **Option B: The Adventure Route (Train + Bus)**
#     *   *If you are coming from Lahore or Karachi:* Take the Economy class train to Rawalpindi first.
#     *   **Train Cost:** PKR 1,500 – 3,500 (Depending on city of origin).
#     *   Then, take the bus from Rawalpindi to Hunza.
# *   **Option C: The Fast Track (Flight)**
#     *   **Route:** PIA Flight from Islamabad to Gilgit.
#     *   **Approx. Cost:** PKR 18,000 – 25,000 (One-way, highly weather-dependent).
#     *   *Note: From Gilgit airport, you will have to take a local Hiace van to Hunza for PKR 500.*
# *   **Local Commuting in Hunza:**
#     *   Instead of renting private Jeeps (which cost PKR 8,000+/day), use local shared public vans (Hiace) for commuting between towns (Aliabad to Karimabad is just PKR 100).
#
# ---
#
# ### 3. Places to Visit
# Here are the must-see spots that you can easily cover in a 5-day trip:
#
# *   **Rakaposhi Viewpoint:** Located on the way to Hunza. Stop here for a cup of tea and a breathtaking view of the 7,788m high Rakaposhi mountain.
# *   **Baltit Fort & Altit Fort:** 800-year-old architectural marvels in Karimabad. They offer a deep dive into the history of the Mirs of Hunza.
# *   **Eagle’s Nest (Duiker):** The highest viewpoint in Hunza. Go here at sunset or sunrise to see the golden light hit 11 major mountain peaks.
# *   **Attabad Lake:** A stunning, bright blue lake. You can do a group boat ride here (approx. PKR 1,000 per boat, split among friends).
# *   **Passu Cones & Hussaini Suspension Bridge:** Take iconic photos with the pointy Passu peaks in the background, and test your courage on the thrilling Hussaini Bridge (entry fee: approx. PKR 200).
# *   **Khunjerab Pass (Pakistan-China Border):** The highest paved international border crossing in the world. (You can pool money with other travelers to rent a shared Hiace to go here).
#
# ---
#
# ### 4. Food Suggestions (Must-Try Local Dishes)
# Hunza’s cuisine is organic, healthy, and very affordable.
#
# *   **Chapshuro (The Hunza Pizza):** A crusty bread stuffed with seasoned minced meat and onions. It is incredibly filling and costs only **PKR 250 - 400** (easily shared by two).
# *   **Downdo:** A warm, comforting soup made with handmade noodles, mountain herbs, and optional meat. Perfect for chilly evenings. (**PKR 300 - 450**).
# *   **Tumuro Tea:** A local herbal tea made from wild thyme collected from the mountains. Great for digestion and keeping warm. (**PKR 80 - 150 per cup**).
# *   **Diram Fitti:** A sweet dish made of sprouted wheat and apricot oil—energy food for hiking!
# *   **Local Apricots & Cherries:** If you visit in summer, you can often pick these fresh from the trees for free, or buy a huge bag from locals for just **PKR 200**.
#
# ---
#
# ### 5. Money-Saving Tips for Students
#
# 1.  **Flash Your Student ID:** Always carry your university card. Altit Fort, Baltit Fort, and national parks offer up to **50% discount** on entry tickets for students.
# 2.  **Travel in a Group (Group of 4 or 8 is Ideal):** Hotel rooms in Hunza (budget category: PKR 3,000–5,000 per night) usually have two double beds. Splitting this cost among 4 friends makes it extremely cheap (PKR 1,000 per person/night).
# 3.  **Ditch the Fancy Cafes:** Eat at local *Dhabas* (eateries) in Aliabad or Karimabad bazar instead of high-end tourist restaurants. You will get authentic food at 1/3rd of the price.
# 4.  **Use Public Hiace Vans:** Avoid private cabs. Walk or use the local shared public transport to travel between Karimabad, Aliabad, and Ghalapan.
# 5.  **Pack Wisely:** Bring your own water bottle (you can refill it with clean, cold mountain spring water for free), snacks, and warm clothes so you don't have to buy expensive gear there.
#
# Safe travels! Let me know if you want me to customize this further or provide a day-by-day itinerary!
